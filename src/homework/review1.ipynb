# %% [markdown]
# # 复习题

# %% [markdown]
# ## 什么是卡方检验

# %% [markdown]
# 当自变量$X$和因变量$Y$均为分类特征(即等级资料)时,
# 可以通过统计频次($Y$为某一值得次数)
# 或者频率计算用特征$X$分组后不同组间的差别是否具有统计学意义，
# 判断特征值$X$的重要性，
# 这种检验称为卡方检验。
# 卡方检验是非参数检验方法，
# 对资料没有特殊要求，
# 尤其适用于样本量较小的情况。

# %% [markdown]
# ## 喝牛奶与感冒的相关性
# 写$H_0$,$H_1$

# %% [markdown]
# -   $H_0$: 喝牛奶与感冒无显著差别
#
# -   $H_1$: 喝牛奶与感冒有显著差别
#
# [reference](https://www.bioinfo-scrounger.com/archives/603/)

# %% [markdown]
# ## 判断5种品牌啤酒的爱好者有无显著差异，写出代码
# | 喜欢的牌子 | A   | B   | C   | D   | E   |
# |:---------- |:--- | --- | --- | --- | --- |
# | 人数$X$    | 210 | 312 | 170 | 85  | 223 |

# %%
people = c(210,312,170,85,223)
bands = c(0,1,2,3,4)
cor.test(people,bands)
# Out:
# 	Pearson's product-moment correlation
#
# data:  people and bands
# t = -0.72189, df = 3, p-value = 0.5225
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.9459162  0.7532090
# sample estimates:
#        cor
# -0.3847075

# %%
chisq.test(people)
# Out:
# 	Chi-squared test for given probabilities
#
# data:  people
# X-squared = 136.49, df = 4, p-value < 2.2e-16

# %% [markdown]
# `p-value = 0.5225` 接受原假设，即5种品牌爱好者有显著性差异

# %% [markdown]
# ## 使用ForestData数据，绘制森林地区各月份温度的箱线图

# %%
forest = read.table("ForestData.txt",header=TRUE)
forest
# Out:
#     X Y month day temp RH wind rain area
# 1   1 2 aug   fri 14.7 66 2.7  0      0.00
# 2   1 2 aug   fri 18.5 73 8.5  0      0.00
# 3   1 2 aug   fri 25.9 41 3.6  0      0.00
# 4   1 2 aug   sat 25.9 32 3.1  0      0.00
# 5   1 2 aug   sun 19.5 39 6.3  0      0.00
# 6   1 2 aug   sun 17.9 44 2.2  0      0.00
# 7   1 2 aug   thu 20.2 45 3.6  0      0.00
# 8   1 2 aug   thu 26.7 35 1.8  0      5.80
# 9   1 2 aug   tue 21.6 19 6.7  0      0.00
# 10  1 2 aug   tue 18.6 51 4.5  0      0.00
# 11  1 2 aug   wed 16.6 47 0.9  0      0.00
# 12  1 2 aug   wed 23.3 31 4.5  0      0.55
# 13  1 2 jul   fri 14.8 78 8.0  0      0.00
# 14  1 2 jul   sat 16.6 53 5.4  0      0.71
# 15  1 2 sep   sun 25.3 36 3.6  0      0.00
# 16  1 2 sep   thu 21.5 15 0.9  0      0.00
# 17  1 2 sep   thu 25.4 27 2.2  0      0.00
# 18  1 2 sep   thu 22.4 34 2.2  0      0.00
# 19  1 2 sep   tue 18.8 40 2.2  0    212.88
# 20  1 3 aug   fri 32.4 27 2.2  0      0.00
# 21  1 3 aug   fri 27.5 29 4.5  0     43.32
# 22  1 3 aug   sat 23.3 40 4.0  0      6.36
# 23  1 3 aug   thu 26.2 34 5.8  0      0.00
# 24  1 3 mar   mon  8.3 72 3.1  0      0.00
# 25  1 3 sep   fri 19.1 46 2.2  0      0.33
# 26  1 3 sep   mon 12.4 73 6.3  0     30.32
# 27  1 3 sep   sat 22.3 48 4.0  0      0.72
# 28  1 3 sep   sun 23.9 32 6.7  0      5.33
# 29  1 3 sep   sun 21.9 43 4.0  0     70.76
# 30  1 4 aug   fri 22.2 45 3.6  0      0.00
# ⋮   ⋮ ⋮ ⋮     ⋮   ⋮    ⋮  ⋮    ⋮    ⋮
# 488 8 6 jul   tue 17.1 67 3.6  0.0    6.57
# 489 8 6 jun   sun 15.4 45 2.2  0.0    0.00
# 490 8 6 jun   wed 19.6 43 4.9  0.0    0.00
# 491 8 6 mar   fri  8.3 97 4.0  0.2    0.00
# 492 8 6 mar   fri 17.4 24 5.4  0.0    0.00
# 493 8 6 mar   sun 11.4 99 1.8  0.0    0.00
# 494 8 6 mar   sun 11.5 39 5.8  0.0    7.19
# 495 8 6 oct   mon 19.1 32 4.0  0.0    5.44
# 496 8 6 oct   wed 20.2 37 2.7  0.0   13.70
# 497 8 6 sep   fri 20.7 46 2.7  0.0   30.18
# 498 8 6 sep   mon 22.7 35 2.2  0.0    7.48
# 499 8 6 sep   mon 15.7 51 2.2  0.0    0.00
# 500 8 6 sep   mon 15.9 51 4.5  0.0    2.18
# 501 8 6 sep   sat 17.8 56 1.8  0.0    1.95
# 502 8 6 sep   thu 23.7 25 4.5  0.0    1.12
# 503 8 6 sep   tue 13.1 63 5.4  0.0    0.00
# 504 8 8 aug   wed 26.2 36 4.5  0.0  185.76
# 505 9 4 jul   mon 22.8 27 4.5  0.0    1.63
# 506 9 4 jul   sat 25.3 39 0.9  0.0    8.00
# 507 9 4 jun   sat 24.5 50 3.1  0.0   70.32
# 508 9 4 sep   tue 24.3 36 3.1  0.0  105.66
# 509 9 5 jun   wed 28.0 34 4.5  0.0    0.00
# 510 9 5 jun   wed 28.0 34 4.5  0.0    8.16
# 511 9 6 aug   thu 20.5 58 2.7  0.0   42.87
# 512 9 9 aug   fri 25.0 36 4.0  0.0    0.00
# 513 9 9 feb   fri 15.7 43 3.1  0.0    0.00
# 514 9 9 feb   thu  6.7 79 3.1  0.0    0.00
# 515 9 9 jul   sun 24.8 29 2.2  0.0    1.36
# 516 9 9 jul   thu 30.2 25 4.5  0.0    2.75
# 517 9 9 jul   tue 18.0 42 2.7  0.0    0.36

# %%
# boxplot(forest$temp)
boxplot(temp~month,data=forest,main='森林各地区温度箱线图')
# Out:
# Plot with title “森林各地区温度箱线图”

# %% [markdown]
# ## 使用ForestData数据，绘制各月份温度的直方图和带正态分布曲线的直方图，核密度图

# %%
# hist(forest$temp) # 好像必须加参数 freq = FALSE， 转换成频率，否则看不出来
hist(forest$temp,xlab='温度',ylab='频率',main='森林地区温度分布直方图',freq = FALSE)
temp_mean = mean(forest$temp,rm.na=TRUE)
temp_std = sd(forest$temp)
x = seq(from=min(forest$temp),to=max(forest$temp),length.out=length(forest$temp))
curve(dnorm(x,temp_mean,temp_std),add=TRUE)
# lines(density(forest$temp),lty=4,col=4)
# curve(dnorm(),add=TRUE)
# Out:
# Plot with title “温度分布直方图”

# %%
# 核密度曲线
plot(density(forest$temp))
# Out:
# Plot with title “density.default(x = forest$temp)”

# %% [markdown]
# ## 使用ReportCard数据，得到avScore的频数图，并画出其直方图

# %%
rc = read.table('ReportCard.txt',header=TRUE)
rc = na.omit(rc)
rc
# Out:
#    xh    sex poli chi  math fore phy che geo  his sumScore avScore
# 1  92101 F   96   96.0 87.5 72   93  65  76.0 92  677.5    B
# 2  92102 M   94   97.0 86.5 61   93  64  79.5 95  670.0    B
# 4  92104 F   89   97.0 69.5 86   83  62  83.0 94  663.5    B
# 5  92105 M   82   85.0 79.5 60   88  66  72.5 98  631.0    C
# 6  92106 F   88   88.0 78.0 60   90  70  81.5 77  632.5    C
# 7  92108 F   84   90.0 69.5 50   80  60  86.5 94  614.0    C
# 8  92110 M   92   94.0 71.0 65   78  62  83.0 87  632.0    C
# 9  92111 M   61   86.0 74.0 51   74  61  76.0 91  574.0    C
# 10 92112 F   81   75.5 76.5 43   78  83  78.0 91  606.0    C
# 11 92113 M   70   85.0 66.0 63   86  65  64.0 84  583.0    C
# 12 92115 M   85   91.0 72.5 63   70  50  65.0 82  578.5    C
# 13 92116 F   84   87.0 67.5 52   82  60  79.0 71  582.5    C
# 14 92117 M   83   91.0 80.5 44   89  56  55.0 62  560.5    C
# 15 92120 M   90   84.0 55.0 50   82  60  67.5 81  569.5    C
# 16 92122 M   80   88.5 63.5 44   75  70  61.5 66  548.5    D
# 17 92124 M   82   76.0 61.0 42   80  50  60.0 87  538.0    D
# 18 92125 F   88   80.0 53.5 60   78  51  69.0 94  573.5    C
# 19 92126 M   70   92.0 56.0 40   66  56  70.5 91  541.5    D
# 20 92127 F   87   97.0 52.0 38   76  47  79.0 84  560.0    C
# 21 92128 F   76   93.0 45.0 65   68  60  64.5 73  544.5    D
# 22 92129 F   89   90.0 50.0 52   71  53  58.0 74  537.0    D
# 23 92134 F   77   91.0 47.5 31   67  41  72.5 77  504.0    D
# 24 92135 M   91   77.0 47.0 44   58  44  62.0 80  503.0    D
# 25 92140 F   76   73.0 39.5 41   62  48  54.5 56  450.0    E
# 26 92141 F   73   82.0 41.5 28   69  43  43.0 74  453.5    E
# 28 92144 M   59   79.0 34.0 34   57  37  37.0 76  413.0    E
# 29 92145 M   74   84.5 30.5 33   64  34  34.0 71  425.0    E
# 30 92146 M   61   69.0 45.0 20   49  32  32.0 51  359.0    E
# 31 92202 M   78   89.0 83.5 81   91  77  81.0 93  673.5    B
# 32 92203 F   74   93.0 84.5 50   89  72  82.5 92  637.0    C
# 33 92204 F   88   81.0 87.5 60   84  63  79.0 92  634.5    C
# 34 92205 F   81   79.0 84.0 60   91  64  81.0 92  632.0    C
# 35 92206 F   86   86.0 77.5 40   92  60  57.0 76  574.5    C
# 36 92207 F   83   91.0 70.5 60   84  64  81.5 62  596.0    C
# 37 92208 M   91   88.0 63.0 48   75  54  76.0 95  590.0    C
# 38 92209 F   90   91.0 70.5 39   89  53  68.5 81  582.0    C
# 39 92211 F   71   73.0 69.0 42   95  61  76.5 76  563.5    C
# 40 92212 M   84   85.0 61.5 60   78  41  74.0 91  574.5    C
# 41 92213 M   82   76.0 65.0 60   75  60  78.0 76  572.0    C
# 42 92214 M   86   86.0 62.0 50   73  65  63.5 81  566.5    C
# 43 92215 M   83   80.5 62.5 54   60  55  66.5 94  555.5    D
# 44 92216 M   87   74.5 69.5 50   83  47  65.0 72  548.0    D
# 45 92217 F   60   82.5 76.5 35   81  60  70.5 74  539.5    D
# 46 92218 M   87   72.0 70.0 65   72  49  62.0 68  545.0    D
# 47 92220 F   74   81.5 59.5 45   82  64  63.0 72  541.0    D
# 48 92221 F   79   83.0 47.0 51   70  52  77.5 93  552.5    D
# 49 92223 M   56   91.0 65.5 68   77  39  54.5 63  514.0    D
# 50 92224 F   84   72.0 66.5 52   70  43  55.0 69  511.5    D
# 51 92225 M   87   83.0 44.5 46   80  48  64.5 80  533.0    D
# 52 92226 M   73   77.0 52.5 39   81  44  78.0 73  517.5    D
# 53 92227 M   77   87.0 44.5 56   51  44  65.0 86  510.5    D
# 54 92228 M   76   82.0 45.5 60   62  48  51.5 77  502.0    D
# 55 92229 F   83   72.0 44.5 48   50  55  54.0 96  502.5    D
# 56 92231 F   83   84.0 38.5 60   76  46  65.5 49  502.0    D
# 57 92232 F   89   67.0 51.5 30   60  43  61.5 79  481.0    D
# 58 92234 M   66   79.0 55.5 57   52  57  41.0 65  472.5    E
# 59 92236 M   79   76.0 34.0 28   63  36  36.0 52  404.0    E
# 60 92239 F   40   63.0 44.0 21   54  26  26.0 55  329.0    E

# %%
table(rc$avScore)
# Out:
#  B  C  D  E
#  4 24 22  8

# %%
barplot(table(rc$avScore),xlab='平均分等级',ylab='人数',ylim=c(0,25))
# Out:
# plot without title

# %%
hist(table(rc$avScore))
# Out:
# Plot with title “Histogram of table(rc$avScore)”

# %% [markdown]
# ## 使用ForestData，做出RH和Temp的散点图，并在图上添加线性拟合线

# %%
# plot(forest$RH,forest$Temp)
plot(RH~temp, data=forest)
# Out:
# plot without title

# %%
line = lm(RH ~ temp,data=forest)
line
# Out:
# Call:
# lm(formula = RH ~ temp, data = forest)
#
# Coefficients:
# (Intercept)         temp
#      72.283       -1.482

# %%
# plot(forest$RH,forest$Temp)
plot(RH~temp,data=forest)
# abline(lm(forest$RH ~ forest$temp))
# m0 = lm(RH ~ temp,data=forest)
# abline(line$cofficients,col='red')
abline(line,col='red')
# Out:
# plot without title

# %%
cor.test(forest$RH, forest$temp)
# Out:
# 	Pearson's product-moment correlation
#
# data:  forest$RH and forest$temp
# t = -14.087, df = 515, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.5869323 -0.4621744
# sample estimates:
#        cor
# -0.5273903

# %% [markdown]
# ## 使用ForestData，做出temp，RH和wind的矩阵散点图，即直观显示多对数值型变量的相关性

# %%
forest[5:7]
# Out:
#     temp RH wind
# 1   14.7 66 2.7
# 2   18.5 73 8.5
# 3   25.9 41 3.6
# 4   25.9 32 3.1
# 5   19.5 39 6.3
# 6   17.9 44 2.2
# 7   20.2 45 3.6
# 8   26.7 35 1.8
# 9   21.6 19 6.7
# 10  18.6 51 4.5
# 11  16.6 47 0.9
# 12  23.3 31 4.5
# 13  14.8 78 8.0
# 14  16.6 53 5.4
# 15  25.3 36 3.6
# 16  21.5 15 0.9
# 17  25.4 27 2.2
# 18  22.4 34 2.2
# 19  18.8 40 2.2
# 20  32.4 27 2.2
# 21  27.5 29 4.5
# 22  23.3 40 4.0
# 23  26.2 34 5.8
# 24   8.3 72 3.1
# 25  19.1 46 2.2
# 26  12.4 73 6.3
# 27  22.3 48 4.0
# 28  23.9 32 6.7
# 29  21.9 43 4.0
# 30  22.2 45 3.6
# ⋮   ⋮    ⋮  ⋮
# 488 17.1 67 3.6
# 489 15.4 45 2.2
# 490 19.6 43 4.9
# 491  8.3 97 4.0
# 492 17.4 24 5.4
# 493 11.4 99 1.8
# 494 11.5 39 5.8
# 495 19.1 32 4.0
# 496 20.2 37 2.7
# 497 20.7 46 2.7
# 498 22.7 35 2.2
# 499 15.7 51 2.2
# 500 15.9 51 4.5
# 501 17.8 56 1.8
# 502 23.7 25 4.5
# 503 13.1 63 5.4
# 504 26.2 36 4.5
# 505 22.8 27 4.5
# 506 25.3 39 0.9
# 507 24.5 50 3.1
# 508 24.3 36 3.1
# 509 28.0 34 4.5
# 510 28.0 34 4.5
# 511 20.5 58 2.7
# 512 25.0 36 4.0
# 513 15.7 43 3.1
# 514  6.7 79 3.1
# 515 24.8 29 2.2
# 516 30.2 25 4.5
# 517 18.0 42 2.7

# %%
pairs(forest[5:7])
# Out:
# plot without title
